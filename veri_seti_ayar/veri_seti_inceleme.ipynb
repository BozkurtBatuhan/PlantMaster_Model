# %%
import os

# %%
data_dir = r'C:\Users\Bilal\Desktop\SonVeri\DuzenlenmisPG-tts\train'

# %%
class_counts = {}

for class_name in os.listdir(data_dir):
    class_path = os.path.join(data_dir, class_name)
    
    if os.path.isdir(class_path):
        num_images = len(os.listdir(class_path))
        class_counts[class_name] = num_images

# %%
sorted_counts = dict(sorted(class_counts.items(), key=lambda x: x[1], reverse=True))

# %%
for cls, count in sorted_counts.items():
    print(f'{cls}: {count}')
# Out:
# Soybean___healthy: 2021
# Apple___Apple_scab: 2016
# Orange___Haunglongbing_(Citrus_greening): 2010
# Apple___healthy: 2008
# Pepper,_bell___healthy: 1988
# Apple___Black_rot: 1987
# Tomato___Tomato_Yellow_Leaf_Curl_Virus: 1960
# Potato___Early_blight: 1939
# Potato___Late_blight: 1939
# Tomato___healthy: 1925
# Grape___Esca_(Black_Measles): 1920
# Tomato___Early_blight: 1920
# Pepper,_bell___Bacterial_spot: 1912
# Corn_(maize)___Northern_Leaf_Blight: 1908
# Corn_(maize)___Common_rust_: 1907
# Grape___Black_rot: 1888
# Tomato___Leaf_Mold: 1881
# Corn_(maize)___healthy: 1859
# Tomato___Late_blight: 1851
# Peach___Bacterial_spot: 1837
# Tomato___Target_Spot: 1827
# Cherry_(including_sour)___healthy: 1825
# Potato___healthy: 1824
# Strawberry___healthy: 1824
# Blueberry___healthy: 1816
# Tomato___Tomato_mosaic_virus: 1790
# Raspberry___healthy: 1780
# Strawberry___Leaf_scorch: 1774
# Apple___Cedar_apple_rust: 1760
# Tomato___Septoria_leaf_spot: 1744
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 6))
plt.bar(sorted_counts.keys(), sorted_counts.values())
plt.xticks(rotation=90)
plt.ylabel("Image Count")
plt.title("Class Distribution in PlantVillage Dataset")
plt.tight_layout()
plt.show()
